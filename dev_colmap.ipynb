# %% [markdown]
# # Colmap container

# %%
import docker
serial = str(2)

path_to_mount = '/home/liteandfog/raspi-plant/d/dataset'+serial
path_masked_to_mount = '/home/liteandfog/raspi-plant/d2'
path_output_to_mount = '/home/liteandfog/raspi-plant/output2'

WD="/root/data"
destination_mount = '/root/data/dataset'
destination_masked_mount = '/root/data/dataset-m'
destination_output_mount = '/root/data/output'

mount_dict = {path_to_mount: {'bind': destination_mount, 'mode': 'rw'},
              path_masked_to_mount: {'bind': destination_masked_mount, 'mode': 'rw'},
              path_output_to_mount: {'bind': destination_output_mount, 'mode': 'rw'}}

#library structure inside the docker container.
DATASET_PATH="/root/data"

DATABASE_PATH="/root/data/output/database.db"

IMAGESET_PATH="/root/data/dataset-m"

OUTPUT_PATH="/root/data/output"

SPARSE_PATH="/root/data/output/0"

NEW_SPARSE_PATH="/root/data/output/sparse"

DENSE_PATH="/root/data/output"

DENSE_PLY_PATH="/root/data/output/dense.ply"

# %% [markdown]
# # COLMAP's pipeline

# %%
# feature_extractor
CMD1 = f"colmap feature_extractor --database_path {DATABASE_PATH} --image_path {IMAGESET_PATH}"

# exhaustive_matcher
CMD2 = f"colmap exhaustive_matcher \
   --database_path {DATABASE_PATH}"

# colmap mapper
CMD3 = f"colmap mapper \
    --database_path {DATABASE_PATH} \
    --image_path {IMAGESET_PATH} \
    --output_path {OUTPUT_PATH}"

# colmap image_undistorter
CMD4 = f"colmap image_undistorter \
    --image_path {IMAGESET_PATH} \
    --input_path {SPARSE_PATH} \
    --output_path {DENSE_PATH} \
    --output_type COLMAP"

# colmap patch_match_stereo
CMD5 = f"colmap patch_match_stereo \
    --workspace_path {DENSE_PATH} \
    --workspace_format COLMAP \
    --PatchMatchStereo.geom_consistency true"

# colmap stereo_fusion
CMD6 = f"colmap stereo_fusion \
    --workspace_path {DENSE_PATH} \
    --workspace_format COLMAP \
    --input_type geometric \
    --output_path {DENSE_PLY_PATH}"

### converter (bytes into text)
CMD7 = f"colmap model_converter \
    --input_path {SPARSE_PATH} \
    --output_path {SPARSE_PATH} \
    --output_type BIN"

# %%
# %%time
client = docker.from_env()
# Out:
# CPU times: user 7.84 ms, sys: 615 µs, total: 8.46 ms
# Wall time: 64.3 ms

# %%
# %%time
client.containers.run('colmap:test', CMD1 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False, auto_remove=True)
# Out:
# CPU times: user 55.9 ms, sys: 6.15 ms, total: 62.1 ms
# Wall time: 50.9 s
# b'\n==============================================================================\nFeature extraction\n==============================================================================\n\nProcessed file [1/180]\n  Name:            1638793105-943135/52img0-89.jpg\n  Dimensions:      640 x 480\n  Camera:          #1 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        487\nProcessed file [2/180]\n  Name:            1638793105-943135/52img1-37.jpg\n  Dimensions:      640 x 480\n  Camera:          #2 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        482\nProcessed file [3/180]\n  Name:            1638793105-943135/52img1-88.jpg\n  Dimensions:      640 x 480\n  Camera:          #3 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        454\nProcessed file [4/180]\n  Name:            1638793105-943135/52img2-37.jpg\n  Dimensions:      640 x 480\n  Camera:          #4 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        510\nProcessed file [5/180]\n  Name:            1638793105-943135/52img2-88.jpg\n  Dimensions:      640 x 480\n  Camera:          #5 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        483\nProcessed file [6/180]\n  Name:            1638793105-943135/52img3-37.jpg\n  Dimensions:      640 x 480\n  Camera:          #6 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        479\nProcessed file [7/180]\n  Name:            1638793105-943135/52img3-88.jpg\n  Dimensions:      640 x 480\n  Camera:          #7 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        481\nProcessed file [8/180]\n  Name:            1638793105-943135/52img4-36.jpg\n  Dimensions:      640 x 480\n  Camera:          #8 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        469\nProcessed file [9/180]\n  Name:            1638793105-943135/56img0-90.jpg\n  Dimensions:      640 x 480\n  Camera:          #9 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        780\nProcessed file [10/180]\n  Name:            1638793105-943135/56img0-96.jpg\n  Dimensions:      640 x 480\n  Camera:          #10 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        781\nProcessed file [11/180]\n  Name:            1638793105-943135/56img1-90.jpg\n  Dimensions:      640 x 480\n  Camera:          #11 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        732\nProcessed file [12/180]\n  Name:            1638793105-943135/56img2-38.jpg\n  Dimensions:      640 x 480\n  Camera:          #12 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        754\nProcessed file [13/180]\n  Name:            1638793105-943135/56img2-89.jpg\n  Dimensions:      640 x 480\n  Camera:          #13 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        779\nProcessed file [14/180]\n  Name:            1638793105-943135/56img3-38.jpg\n  Dimensions:      640 x 480\n  Camera:          #14 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        786\nProcessed file [15/180]\n  Name:            1638793105-943135/56img3-90.jpg\n  Dimensions:      640 x 480\n  Camera:          #15 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        790\nProcessed file [16/180]\n  Name:            1638793105-943135/56img4-38.jpg\n  Dimensions:      640 x 480\n  Camera:          #16 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        772\nProcessed file [17/180]\n  Name:            1638796124-604306/52img0-89.jpg\n  Dimensions:      640 x 480\n  Camera:          #17 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        556\nProcessed file [18/180]\n  Name:            1638796124-604306/52img1-37.jpg\n  Dimensions:      640 x 480\n  Camera:          #18 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        551\nProcessed file [19/180]\n  Name:            1638796124-604306/52img1-88.jpg\n  Dimensions:      640 x 480\n  Camera:          #19 - SIMPLE_RADIAL\n  Focal Length:    768.00px\n  Features:        524\nProcessed file [20/180]\n  Name: ...

# %%
# %%time
client.containers.run('colmap:test', CMD2 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 30.3 ms, sys: 188 µs, total: 30.5 ms
# Wall time: 51.1 s
# b'\n==============================================================================\nExhaustive feature matching\n==============================================================================\n\nMatching block [1/4, 1/4] in 0.268s\nMatching block [1/4, 2/4] in 0.135s\nMatching block [1/4, 3/4] in 0.170s\nMatching block [1/4, 4/4] in 0.060s\nMatching block [2/4, 1/4] in 0.142s\nMatching block [2/4, 2/4] in 0.143s\nMatching block [2/4, 3/4] in 0.138s\nMatching block [2/4, 4/4] in 0.058s\nMatching block [3/4, 1/4] in 0.162s\nMatching block [3/4, 2/4] in 0.130s\nMatching block [3/4, 3/4] in 0.151s\nMatching block [3/4, 4/4] in 0.052s\nMatching block [4/4, 1/4] in 0.144s\nMatching block [4/4, 2/4] in 0.120s\nMatching block [4/4, 3/4] in 0.126s\nMatching block [4/4, 4/4] in 0.075s\nElapsed time: 0.837 [minutes]\n'

# %%
# %%time
client.containers.run('colmap:test', CMD3 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 491 ms, sys: 15.9 ms, total: 507 ms
# Wall time: 3min 24s
# b"\n==============================================================================\nLoading database\n==============================================================================\n\nLoading cameras... 180 in 0.000s\nLoading matches... 1288 in 0.007s\nLoading images... 180 in 0.009s (connected 180)\nBuilding correspondence graph... in 0.017s (ignored 0)\n\nElapsed time: 0.001 [minutes]\n\n\n==============================================================================\nFinding good initial image pair\n==============================================================================\n\n\n==============================================================================\nInitializing with image pair #162 and #164\n==============================================================================\n\n\n==============================================================================\nGlobal bundle adjustment\n==============================================================================\n\niter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time\n   0  2.229470e+01    0.00e+00    6.70e+02   0.00e+00   0.00e+00  1.00e+04        0    8.39e-04    2.38e-03\n   1  2.193904e+01    3.56e-01    6.84e+02   8.08e+00   3.39e-01  9.68e+03        1    1.43e-03    3.82e-03\n   2  2.123081e+01    7.08e-01    6.67e+01   1.03e+01   9.94e-01  2.90e+04        1    5.42e-04    4.37e-03\n   3  2.117818e+01    5.26e-02    1.31e+02   2.32e+01   6.27e-01  2.95e+04        1    5.39e-04    4.92e-03\n   4  2.111689e+01    6.13e-02    6.08e+01   1.72e+01   8.96e-01  5.85e+04        1    5.43e-04    5.47e-03\n   5  2.109280e+01    2.41e-02    7.26e+01   1.98e+01   6.91e-01  6.19e+04        1    5.43e-04    6.02e-03\n   6  2.107431e+01    1.85e-02    2.82e+01   1.21e+01   9.29e-01  1.68e+05        1    5.40e-04    6.56e-03\n   7  2.106966e+01    4.66e-03    2.31e+01   1.14e+01   8.12e-01  2.22e+05        1    5.41e-04    7.11e-03\n   8  2.106810e+01    1.55e-03    3.66e+00   4.25e+00   9.94e-01  6.66e+05        1    5.58e-04    7.67e-03\n   9  2.106803e+01    7.55e-05    1.86e+00   1.62e+00   1.01e+00  2.00e+06        1    5.40e-04    8.22e-03\n  10  2.106803e+01    1.93e-06    1.88e-01   1.80e-01   1.07e+00  5.99e+06        1    5.38e-04    8.77e-03\n  11  2.106803e+01    3.66e-08    8.29e-02   1.59e-02   1.04e+00  1.80e+07        1    5.39e-04    9.31e-03\n\n\nBundle adjustment report\n------------------------\n    Residuals : 408\n   Parameters : 315\n   Iterations : 12\n         Time : 0.00933663 [s]\n Initial cost : 0.23376 [px]\n   Final cost : 0.227238 [px]\n  Termination : Convergence\n\n  => Filtered observations: 0\n  => Filtered images: 0\n\n==============================================================================\nRegistering image #163 (3)\n==============================================================================\n\n  => Image sees 89 / 665 points\n\nPose refinement report\n----------------------\n    Residuals : 178\n   Parameters : 8\n   Iterations : 8\n         Time : 0.00412229 [s]\n Initial cost : 0.859098 [px]\n   Final cost : 0.243017 [px]\n  Termination : Convergence\n\n  => Continued observations: 89\n  => Added observations: 635\n\nBundle adjustment report\n------------------------\n    Residuals : 1856\n   Parameters : 1193\n   Iterations : 26\n         Time : 0.0716873 [s]\n Initial cost : 0.230978 [px]\n   Final cost : 0.220155 [px]\n  Termination : No convergence\n\n  => Merged observations: 4\n  => Completed observations: 0\n  => Filtered observations: 0\n  => Changed observations: 0.004310\n\nBundle adjustment report\n------------------------\n    Residuals : 1856\n   Parameters : 1190\n   Iterations : 24\n         Time : 0.0682046 [s]\n Initial cost : 0.260524 [px]\n   Final cost : 0.256069 [px]\n  Termination : Convergence\n\n  => Merged observations: 0\n  => Completed observations: 0\n  => Filtered observations: 0\n  => Changed observations: 0.000000\n\n============================ ...

# %%
# %%time
client.containers.run('colmap:test', CMD4 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 36 ms, sys: 24 µs, total: 36 ms
# Wall time: 1.09 s
# b'\n==============================================================================\nReading reconstruction\n==============================================================================\n\n => Reconstruction with 90 images and 6603 points\n\n==============================================================================\nImage undistortion\n==============================================================================\n\nUndistorting image [1/90]\nUndistorting image [2/90]\nUndistorting image [3/90]\nUndistorting image [4/90]\nUndistorting image [5/90]\nUndistorting image [6/90]\nUndistorting image [7/90]\nUndistorting image [8/90]\nUndistorting image [9/90]\nUndistorting image [10/90]\nUndistorting image [11/90]\nUndistorting image [12/90]\nUndistorting image [13/90]\nUndistorting image [14/90]\nUndistorting image [15/90]\nUndistorting image [16/90]\nUndistorting image [17/90]\nUndistorting image [18/90]\nUndistorting image [19/90]\nUndistorting image [20/90]\nUndistorting image [21/90]\nUndistorting image [22/90]\nUndistorting image [23/90]\nUndistorting image [24/90]\nUndistorting image [25/90]\nUndistorting image [26/90]\nUndistorting image [27/90]\nUndistorting image [28/90]\nUndistorting image [29/90]\nUndistorting image [30/90]\nUndistorting image [31/90]\nUndistorting image [32/90]\nUndistorting image [33/90]\nUndistorting image [34/90]\nUndistorting image [35/90]\nUndistorting image [36/90]\nUndistorting image [37/90]\nUndistorting image [38/90]\nUndistorting image [39/90]\nUndistorting image [40/90]\nUndistorting image [41/90]\nUndistorting image [42/90]\nUndistorting image [43/90]\nUndistorting image [44/90]\nUndistorting image [45/90]\nUndistorting image [46/90]\nUndistorting image [47/90]\nUndistorting image [48/90]\nUndistorting image [49/90]\nUndistorting image [50/90]\nUndistorting image [51/90]\nUndistorting image [52/90]\nUndistorting image [53/90]\nUndistorting image [54/90]\nUndistorting image [55/90]\nUndistorting image [56/90]\nUndistorting image [57/90]\nUndistorting image [58/90]\nUndistorting image [59/90]\nUndistorting image [60/90]\nUndistorting image [61/90]\nUndistorting image [62/90]\nUndistorting image [63/90]\nUndistorting image [64/90]\nUndistorting image [65/90]\nUndistorting image [66/90]\nUndistorting image [67/90]\nUndistorting image [68/90]\nUndistorting image [69/90]\nUndistorting image [70/90]\nUndistorting image [71/90]\nUndistorting image [72/90]\nUndistorting image [73/90]\nUndistorting image [74/90]\nUndistorting image [75/90]\nUndistorting image [76/90]\nUndistorting image [77/90]\nUndistorting image [78/90]\nUndistorting image [79/90]\nUndistorting image [80/90]\nUndistorting image [81/90]\nUndistorting image [82/90]\nUndistorting image [83/90]\nUndistorting image [84/90]\nUndistorting image [85/90]\nUndistorting image [86/90]\nUndistorting image [87/90]\nUndistorting image [88/90]\nUndistorting image [89/90]\nUndistorting image [90/90]\nWriting reconstruction...\nWriting configuration...\nWriting scripts...\nElapsed time: 0.007 [minutes]\n'

# %%
# %%time
client.containers.run('colmap:test', CMD5 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 300 ms, sys: 29.9 ms, total: 330 ms
# Wall time: 16min 59s
# b'Reading workspace...\nReading configuration...\nConfiguration has 90 problems...\n\n==============================================================================\nProcessing view 1 / 90 for 1638793105-943135/56img0-90.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 40\nsrc_image_idxs: 27 53 26 61 29 39 1 47 32 35 60 37 59 36 0 46 54 31 48 28\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 2.51472\ndepth_max: 5.19033\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consistency_regularizer: 0.3\ngeom_consistency_max_cost: 3\nfilter: 0\nfilter_min_ncc: 0.1\nfilter_min_triangulation_angle: 3\nfilter_min_num_consistent: 2\nfilter_geom_consistency_max_cost: 1\nwrite_consistency_graph: 0\nallow_missing_files: 0\n\nPatchMatch::Run\n---------------\nInitialization: 0.0630s\n Sweep 1: 0.3075s\n Sweep 2: 0.3898s\n Sweep 3: 0.2795s\n Sweep 4: 0.4298s\nIteration 1: 1.4067s\n Sweep 1: 0.2794s\n Sweep 2: 0.3938s\n Sweep 3: 0.2792s\n Sweep 4: 0.3962s\nIteration 2: 1.3487s\n Sweep 1: 0.2792s\n Sweep 2: 0.4173s\n Sweep 3: 0.2787s\n Sweep 4: 0.3925s\nIteration 3: 1.3678s\n Sweep 1: 0.2782s\n Sweep 2: 0.3871s\n Sweep 3: 0.2776s\n Sweep 4: 0.3880s\nIteration 4: 1.3309s\n Sweep 1: 0.2772s\n Sweep 2: 0.3819s\n Sweep 3: 0.2766s\n Sweep 4: 0.3822s\nIteration 5: 1.3180s\nTotal: 6.8352s\n\nWriting photometric output for 1638793105-943135/56img0-90.jpg\n\n==============================================================================\nProcessing view 2 / 90 for 1638793105-943135/56img0-96.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 48\nsrc_image_idxs: 53 62 39 61 26 47 29 36 59 55 32 35 54 31 60 37 40 0 46 28\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 2.72063\ndepth_max: 5.5118\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consistency_regularizer: 0.3\ngeom_consistency_max_cost: 3\nfilter: 0\nfilter_min_ncc: 0.1\nfilter_min_triangulation_angle: 3\nfilter_min_num_consistent: 2\nfilter_geom_consistency_max_cost: 1\nwrite_consistency_graph: 0\nallow_missing_files: 0\n\nPatchMatch::Run\n---------------\nInitialization: 0.0545s\n Sweep 1: 0.2772s\n Sweep 2: 0.3889s\n Sweep 3: 0.2780s\n Sweep 4: 0.3933s\nIteration 1: 1.3374s\n Sweep 1: 0.2773s\n Sweep 2: 0.3916s\n Sweep 3: 0.2778s\n Sweep 4: 0.3899s\nIteration 2: 1.3367s\n Sweep 1: 0.2771s\n Sweep 2: 0.3881s\n Sweep 3: 0.2772s\n Sweep 4: 0.3861s\nIteration 3: 1.3286s\n Sweep 1: 0.2765s\n Sweep 2: 0.3847s\n Sweep 3: 0.2760s\n Sweep 4: 0.3813s\nIteration 4: 1.3185s\n Sweep 1: 0.2754s\n Sweep 2: 0.3789s\n Sweep 3: 0.2753s\n Sweep 4: 0.3761s\nIteration 5: 1.3058s\nTotal: 6.6816s\n\nWriting photometric output for 1638793105-943135/56img0-96.jpg\n\n==============================================================================\nProcessing view 3 / 90 for 1638793105-943135/56img1-90.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 37\nsrc_image_idxs: 39 62 47 53 61 26 60 31 29 63 40 36 59 28 0 46 48 55 32 35\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 2.48842\ndepth_max: 5.16496\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consistency_regularizer: 0.3\ngeom_consistency_max_cost: 3\nfil ...

# %%
# %%time
client.containers.run('colmap:test', CMD6 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 32.2 ms, sys: 368 µs, total: 32.5 ms
# Wall time: 6.44 s
# b'\nStereoFusion::Options\n---------------------\nmask_path: \nmax_image_size: -1\nmin_num_pixels: 5\nmax_num_pixels: 10000\nmax_traversal_depth: 100\nmax_reproj_error: 2\nmax_depth_error: 0.01\nmax_normal_error: 10\ncheck_num_images: 50\nuse_cache: 0\ncache_size: 32\nbbox_min: -3.40282e+38 -3.40282e+38 -3.40282e+38\nbbox_max: 3.40282e+38 3.40282e+38 3.40282e+38\n\nReading workspace...\nLoading workspace data with 16 threads...\nElapsed time: 0.003 [minutes]\nReading configuration...\nStarting fusion with 16 threads\nFusing image [1/90] with index 0 in 0.120s (9313 points)\nFusing image [2/90] with index 54 in 0.105s (14224 points)\nFusing image [3/90] with index 1 in 0.105s (17552 points)\nFusing image [4/90] with index 27 in 0.101s (20689 points)\nFusing image [5/90] with index 2 in 0.092s (22964 points)\nFusing image [6/90] with index 3 in 0.090s (26261 points)\nFusing image [7/90] with index 30 in 0.088s (27571 points)\nFusing image [8/90] with index 33 in 0.088s (29242 points)\nFusing image [9/90] with index 4 in 0.087s (30524 points)\nFusing image [10/90] with index 5 in 0.092s (32534 points)\nFusing image [11/90] with index 38 in 0.083s (33367 points)\nFusing image [12/90] with index 52 in 0.085s (34538 points)\nFusing image [13/90] with index 6 in 0.085s (35279 points)\nFusing image [14/90] with index 44 in 0.083s (35909 points)\nFusing image [15/90] with index 49 in 0.083s (36449 points)\nFusing image [16/90] with index 58 in 0.087s (36830 points)\nFusing image [17/90] with index 41 in 0.003s (37069 points)\nFusing image [18/90] with index 70 in 0.089s (37603 points)\nFusing image [19/90] with index 89 in 0.090s (38270 points)\nFusing image [20/90] with index 69 in 0.002s (38489 points)\nFusing image [21/90] with index 24 in 0.003s (38858 points)\nFusing image [22/90] with index 88 in 0.003s (39014 points)\nFusing image [23/90] with index 18 in 0.005s (39370 points)\nFusing image [24/90] with index 87 in 0.003s (39502 points)\nFusing image [25/90] with index 86 in 0.005s (39848 points)\nFusing image [26/90] with index 20 in 0.003s (39987 points)\nFusing image [27/90] with index 34 in 0.005s (40396 points)\nFusing image [28/90] with index 85 in 0.003s (40570 points)\nFusing image [29/90] with index 84 in 0.004s (41075 points)\nFusing image [30/90] with index 83 in 0.003s (41411 points)\nFusing image [31/90] with index 25 in 0.004s (41736 points)\nFusing image [32/90] with index 17 in 0.004s (42152 points)\nFusing image [33/90] with index 82 in 0.003s (42286 points)\nFusing image [34/90] with index 19 in 0.006s (42974 points)\nFusing image [35/90] with index 81 in 0.090s (45996 points)\nFusing image [36/90] with index 80 in 0.086s (46970 points)\nFusing image [37/90] with index 21 in 0.086s (47334 points)\nFusing image [38/90] with index 79 in 0.084s (47816 points)\nFusing image [39/90] with index 22 in 0.015s (48005 points)\nFusing image [40/90] with index 23 in 0.005s (48141 points)\nFusing image [41/90] with index 78 in 0.003s (48245 points)\nFusing image [42/90] with index 77 in 0.004s (48383 points)\nFusing image [43/90] with index 76 in 0.006s (48800 points)\nFusing image [44/90] with index 75 in 0.006s (49254 points)\nFusing image [45/90] with index 74 in 0.009s (49999 points)\nFusing image [46/90] with index 73 in 0.010s (50749 points)\nFusing image [47/90] with index 50 in 0.008s (51566 points)\nFusing image [48/90] with index 72 in 0.005s (52025 points)\nFusing image [49/90] with index 42 in 0.007s (52652 points)\nFusing image [50/90] with index 71 in 0.007s (53282 points)\nFusing image [51/90] with index 56 in 0.105s (61396 points)\nFusing image [52/90] with index 68 in 0.093s (64244 points)\nFusing image [53/90] with index 7 in 0.089s (67275 points)\nFusing image [54/90] with index 67 in 0.085s (69452 points)\nFusing image [55/90] with index 9 in 0.086s (71973 points)\nFusing image [56/90] with index 51 in 0.085s (73588 points)\nFusing image [57/90] with index 11 in 0.087s (75137 points)\nFusing image [58/90 ...

# %%
# %%time
client.containers.run('colmap:test', CMD7 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False)
# Out:
# CPU times: user 24.6 ms, sys: 32 µs, total: 24.6 ms
# Wall time: 629 ms
# b''

# %% [markdown]
# #  Visualization: dense point cloud

# %%
local_path_to_dense_pc = f"/home/liteandfog/raspi-plant/d/output{4}/dense.ply"

# %%
#local_path_to_dense_pc = "/home/liteandfog/Desktop/raspi-plant/output2/dense.ply"

# %%
import numpy as np
import open3d as o3d

# %%
cloud = o3d.io.read_point_cloud(local_path_to_dense_pc)

# %%
# %%time
o3d.visualization.draw_geometries([cloud])  # Visualize the point cloud
# Out:
# CPU times: user 123 ms, sys: 196 ms, total: 320 ms
# Wall time: 9.46 s

# %% [markdown]
# ####

# %%
##  Visualization: first mesh

# %%
# %%time
poisson_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(cloud, depth=12, width=0, scale=1.1, linear_fit=False)[0]
# Out:
# CPU times: user 17min 2s, sys: 35.6 s, total: 17min 38s
# Wall time: 1min 27s

# %%
o3d.visualization.draw_geometries([poisson_mesh])

# %% [markdown]
# # Outliers and isolated points removal.

# %%
def create_outliers_cloud(pcd):
    pcd_colors = np.asarray(pcd.colors)*255
    pcd_colors_summed = np.expand_dims(pcd_colors.sum(axis=1), axis=1)
    outliers_ind = np.where(np.any(pcd_colors_summed > 720,axis = 1))[0].tolist()
    return pcd.select_by_index(outliers_ind,invert=True),pcd.select_by_index(outliers_ind,invert=False)

# %%
inlier_cloud,outlier_cloud=create_outliers_cloud(cloud)

# %%
o3d.visualization.draw_geometries([inlier_cloud])

# %%
xpcd, _ = inlier_cloud.remove_statistical_outlier(nb_neighbors=5,std_ratio=2.0)

# %%
o3d.visualization.draw_geometries([xpcd])

# %% [markdown]
# ## White pigments outliers

# %%
o3d.visualization.draw_geometries([outlier_cloud])

# %% [markdown]
# # Poisson mesher - cleansed cloud

# %%
poisson_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(xpcd, depth=14, width=0, scale=1.1, linear_fit=False)[0]

# %%
o3d.visualization.draw_geometries([poisson_mesh])
