# %% [markdown]
# # Colmap container

# %%
import docker
serial = str(2)

path_to_mount = '/home/liteandfog/raspi-plant/d/dataset'+serial
path_masked_to_mount = '/home/liteandfog/raspi-plant/d2'
path_output_to_mount = '/home/liteandfog/raspi-plant/output3'

WD="/root/data"
destination_mount = '/root/data/dataset'
destination_masked_mount = '/root/data/dataset-m'
destination_output_mount = '/root/data/output'

mount_dict = {path_to_mount: {'bind': destination_mount, 'mode': 'rw'},
              path_masked_to_mount: {'bind': destination_masked_mount, 'mode': 'rw'},
              path_output_to_mount: {'bind': destination_output_mount, 'mode': 'rw'}}

#directories structure inside the docker container.
DATASET_PATH="/root/data"
DATABASE_PATH="/root/data/output/database.db"
IMAGESET_PATH="/root/data/dataset-m"
OUTPUT_PATH="/root/data/output"
SPARSE_PATH="/root/data/output/0"
NEW_SPARSE_PATH="/root/data/output/sparse"
DENSE_PATH="/root/data/output"
DENSE_PLY_PATH="/root/data/output/dense.ply"

# %% [markdown]
# # COLMAP 3D Reconstruction's pipeline

# %%
# feature_extractor
CMD1 = f"colmap feature_extractor --database_path {DATABASE_PATH} --image_path {IMAGESET_PATH}"
# exhaustive_matcher
CMD2 = f"colmap exhaustive_matcher \
   --database_path {DATABASE_PATH}"
# colmap mapper
CMD3 = f"colmap mapper \
    --database_path {DATABASE_PATH} \
    --image_path {IMAGESET_PATH} \
    --output_path {OUTPUT_PATH}"
# colmap image_undistorter
CMD4 = f"colmap image_undistorter \
    --image_path {IMAGESET_PATH} \
    --input_path {SPARSE_PATH} \
    --output_path {DENSE_PATH} \
    --output_type COLMAP"
# colmap patch_match_stereo
CMD5 = f"colmap patch_match_stereo \
    --workspace_path {DENSE_PATH} \
    --workspace_format COLMAP \
    --PatchMatchStereo.geom_consistency true"
# colmap stereo_fusion
CMD6 = f"colmap stereo_fusion \
    --workspace_path {DENSE_PATH} \
    --workspace_format COLMAP \
    --input_type geometric \
    --output_path {DENSE_PLY_PATH}"
### converter (bytes into text)
CMD7 = f"colmap model_converter \
    --input_path {SPARSE_PATH} \
    --output_path {SPARSE_PATH} \
    --output_type BIN"

# %%
# %%time
client = docker.from_env()
# Out:
# CPU times: user 9.12 ms, sys: 231 µs, total: 9.35 ms
# Wall time: 16.4 ms

# %%
# %%time
client.containers.run('colmap:test', CMD1 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False, auto_remove=True)
# Out:
# CPU times: user 54 ms, sys: 153 µs, total: 54.2 ms
# Wall time: 50.7 s
# b'\n==============================================================================\nFeature extraction\n==============================================================================\n\nProcessed file [1/180]\n  Name:            1641381121-832916/52img0-53.jpg\n  Dimensions:      720 x 1080\n  Camera:          #1 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1167\nProcessed file [2/180]\n  Name:            1641381121-832916/52img0-87.jpg\n  Dimensions:      720 x 1080\n  Camera:          #2 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1205\nProcessed file [3/180]\n  Name:            1641381121-832916/52img1-24.jpg\n  Dimensions:      720 x 1080\n  Camera:          #3 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1208\nProcessed file [4/180]\n  Name:            1641381121-832916/52img1-54.jpg\n  Dimensions:      720 x 1080\n  Camera:          #4 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1139\nProcessed file [5/180]\n  Name:            1641381121-832916/52img1-87.jpg\n  Dimensions:      720 x 1080\n  Camera:          #5 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1074\nProcessed file [6/180]\n  Name:            1641381121-832916/52img10-20.jpg\n  Dimensions:      720 x 1080\n  Camera:          #6 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1325\nProcessed file [7/180]\n  Name:            1641381121-832916/52img10-53.jpg\n  Dimensions:      720 x 1080\n  Camera:          #7 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1272\nProcessed file [8/180]\n  Name:            1641381121-832916/52img10-90.jpg\n  Dimensions:      720 x 1080\n  Camera:          #8 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1287\nProcessed file [9/180]\n  Name:            1641381121-832916/52img11-20.jpg\n  Dimensions:      720 x 1080\n  Camera:          #9 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1235\nProcessed file [10/180]\n  Name:            1641381121-832916/52img11-53.jpg\n  Dimensions:      720 x 1080\n  Camera:          #10 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1299\nProcessed file [11/180]\n  Name:            1641381121-832916/52img11-88.jpg\n  Dimensions:      720 x 1080\n  Camera:          #11 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1187\nProcessed file [12/180]\n  Name:            1641381121-832916/52img12-20.jpg\n  Dimensions:      720 x 1080\n  Camera:          #12 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1172\nProcessed file [13/180]\n  Name:            1641381121-832916/52img12-53.jpg\n  Dimensions:      720 x 1080\n  Camera:          #13 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1262\nProcessed file [14/180]\n  Name:            1641381121-832916/52img12-90.jpg\n  Dimensions:      720 x 1080\n  Camera:          #14 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1174\nProcessed file [15/180]\n  Name:            1641381121-832916/52img13-20.jpg\n  Dimensions:      720 x 1080\n  Camera:          #15 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1180\nProcessed file [16/180]\n  Name:            1641381121-832916/52img13-53.jpg\n  Dimensions:      720 x 1080\n  Camera:          #16 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1130\nProcessed file [17/180]\n  Name:            1641381121-832916/52img13-89.jpg\n  Dimensions:      720 x 1080\n  Camera:          #17 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1096\nProcessed file [18/180]\n  Name:            1641381121-832916/52img14-19.jpg\n  Dimensions:      720 x 1080\n  Camera:          #18 - SIMPLE_RADIAL\n  Focal Length:    1296.00px\n  Features:        1136\nProcessed file [19/180]\n  Name:            1641381121-832916/52img14-53.jpg\n  Dimensions:      720 x 1080\n  Camera:          #19 - SIMPLE_RADIAL\n  Focal Length:  ...

# %%
# %%time
client.containers.run('colmap:test', CMD2 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 21.1 ms, sys: 6.01 ms, total: 27.1 ms
# Wall time: 1min 2s
# b'\n==============================================================================\nExhaustive feature matching\n==============================================================================\n\nMatching block [1/4, 1/4] in 1.102s\nMatching block [1/4, 2/4] in 1.082s\nMatching block [1/4, 3/4] in 0.505s\nMatching block [1/4, 4/4] in 0.240s\nMatching block [2/4, 1/4] in 1.514s\nMatching block [2/4, 2/4] in 1.205s\nMatching block [2/4, 3/4] in 0.786s\nMatching block [2/4, 4/4] in 0.286s\nMatching block [3/4, 1/4] in 1.072s\nMatching block [3/4, 2/4] in 0.987s\nMatching block [3/4, 3/4] in 1.559s\nMatching block [3/4, 4/4] in 0.623s\nMatching block [4/4, 1/4] in 0.439s\nMatching block [4/4, 2/4] in 1.028s\nMatching block [4/4, 3/4] in 1.390s\nMatching block [4/4, 4/4] in 0.529s\nElapsed time: 1.024 [minutes]\n'

# %%
# %%time
client.containers.run('colmap:test', CMD3 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 692 ms, sys: 24.3 ms, total: 717 ms
# Wall time: 10min 49s
# b"\n==============================================================================\nLoading database\n==============================================================================\n\nLoading cameras... 180 in 0.000s\nLoading matches... 5742 in 0.014s\nLoading images... 180 in 0.011s (connected 180)\nBuilding correspondence graph... in 0.030s (ignored 0)\n\nElapsed time: 0.001 [minutes]\n\n\n==============================================================================\nFinding good initial image pair\n==============================================================================\n\n\n==============================================================================\nInitializing with image pair #95 and #153\n==============================================================================\n\n\n==============================================================================\nGlobal bundle adjustment\n==============================================================================\n\niter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time\n   0  1.096338e+02    0.00e+00    7.90e+03   0.00e+00   0.00e+00  1.00e+04        0    4.29e-04    1.26e-03\n   1  6.459241e+01    4.50e+01    8.64e+03   1.24e+02   8.08e-01  1.30e+04        1    7.09e-04    1.99e-03\n   2  4.459353e+01    2.00e+01    7.37e+03   7.76e+01   9.26e-01  3.43e+04        1    5.99e-04    2.60e-03\n   3  5.173047e+01   -7.14e+00    0.00e+00   8.67e+01  -9.49e-01  1.71e+04        1    2.14e-04    2.82e-03\n   4  3.972161e+01    4.87e+00    5.17e+03   5.85e+01   7.78e-01  2.07e+04        1    6.41e-04    3.46e-03\n   5  3.707912e+01    2.64e+00    3.26e+03   4.39e+01   7.68e-01  2.45e+04        1    6.21e-04    4.10e-03\n   6  3.586177e+01    1.22e+00    1.94e+03   3.34e+01   6.75e-01  2.56e+04        1    6.06e-04    4.71e-03\n   7  3.513585e+01    7.26e-01    8.59e+02   2.38e+01   6.80e-01  2.68e+04        1    5.99e-04    5.31e-03\n   8  3.474021e+01    3.96e-01    3.
# Wall time: 1h 50s
# b'Reading workspace...\nReading configuration...\nConfiguration has 162 problems...\n\n==============================================================================\nProcessing view 1 / 162 for 1641381121-832916/52img0-53.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 102\nsrc_image_idxs: 17 115 153 152 73 142 141 95 150 149 74 143 97 144 148 99 145 151 105 147\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 3.01859\ndepth_max: 6.10677\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consistency_regularizer: 0.3\ngeom_consistency_max_cost: 3\nfilter: 0\nfilter_min_ncc: 0.1\nfilter_min_triangulation_angle: 3\nfilter_min_num_consistent: 2\nfilter_geom_consistency_max_cost: 1\nwrite_consistency_graph: 0\nallow_missing_files: 0\n\nPatchMatch::Run\n---------------\nInitialization: 0.1559s\n Sweep 1: 0.6831s\n Sweep 2: 0.5436s\n Sweep 3: 0.6804s\n Sweep 4: 0.5471s\nIteration 1: 2.4543s\n Sweep 1: 0.6663s\n Sweep 2: 0.5331s\n Sweep 3: 0.6770s\n Sweep 4: 0.5369s\nIteration 2: 2.4134s\n Sweep 1: 0.6651s\n Sweep 2: 0.5234s\n Sweep 3: 0.6746s\n Sweep 4: 0.5286s\nIteration 3: 2.3918s\n Sweep 1: 0.6639s\n Sweep 2: 0.5149s\n Sweep 3: 0.6704s\n Sweep 4: 0.5197s\nIteration 4: 2.3690s\n Sweep 1: 0.6590s\n Sweep 2: 0.5049s\n Sweep 3: 0.6691s\n Sweep 4: 0.5100s\nIteration 5: 2.3432s\nTotal: 12.1277s\n\nWriting photometric output for 1641381121-832916/52img0-53.jpg\n\n==============================================================================\nProcessing view 2 / 162 for 1641381121-832916/52img0-87.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 105\nsrc_image_idxs: 157 153 142 73 152 151 144 150 118 95 149 143 74 97 100 146 145 99 102 148\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 2.94993\ndepth_max: 5.80609\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consistency_regularizer: 0.3\ngeom_consistency_max_cost: 3\nfilter: 0\nfilter_min_ncc: 0.1\nfilter_min_triangulation_angle: 3\nfilter_min_num_consistent: 2\nfilter_geom_consistency_max_cost: 1\nwrite_consistency_graph: 0\nallow_missing_files: 0\n\nPatchMatch::Run\n---------------\nInitialization: 0.1364s\n Sweep 1: 0.6699s\n Sweep 2: 0.5412s\n Sweep 3: 0.6826s\n Sweep 4: 0.5475s\nIteration 1: 2.4413s\n Sweep 1: 0.6712s\n Sweep 2: 0.5315s\n Sweep 3: 0.6768s\n Sweep 4: 0.5375s\nIteration 2: 2.4170s\n Sweep 1: 0.6705s\n Sweep 2: 0.5219s\n Sweep 3: 0.6752s\n Sweep 4: 0.5286s\nIteration 3: 2.3962s\n Sweep 1: 0.6693s\n Sweep 2: 0.5133s\n Sweep 3: 0.6729s\n Sweep 4: 0.5197s\nIteration 4: 2.3754s\n Sweep 1: 0.6661s\n Sweep 2: 0.5028s\n Sweep 3: 0.6729s\n Sweep 4: 0.5096s\nIteration 5: 2.3515s\nTotal: 12.1179s\n\nWriting photometric output for 1641381121-832916/52img0-87.jpg\n\n==============================================================================\nProcessing view 3 / 162 for 1641381121-832916/52img1-24.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 99\nsrc_image_idxs: 154 157 153 144 73 152 145 118 95 150 100 146 102 143 74 97 149 147 151 105\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 2.96641\ndepth_max: 5.82155\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consi ...

# %%
# %%time
client.containers.run('colmap:test', CMD6 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 30.1 ms, sys: 1.29 ms, total: 31.4 ms
# Wall time: 29.8 s
# b'\nStereoFusion::Options\n---------------------\nmask_path: \nmax_image_size: -1\nmin_num_pixels: 5\nmax_num_pixels: 10000\nmax_traversal_depth: 100\nmax_reproj_error: 2\nmax_depth_error: 0.01\nmax_normal_error: 10\ncheck_num_images: 50\nuse_cache: 0\ncache_size: 32\nbbox_min: -3.40282e+38 -3.40282e+38 -3.40282e+38\nbbox_max: 3.40282e+38 3.40282e+38 3.40282e+38\n\nReading workspace...\nLoading workspace data with 16 threads...\nElapsed time: 0.015 [minutes]\nReading configuration...\nStarting fusion with 16 threads\nFusing image [1/162] with index 0 in 0.289s (16135 points)\nFusing image [2/162] with index 106 in 0.224s (24763 points)\nFusing image [3/162] with index 109 in 0.221s (31459 points)\nFusing image [4/162] with index 111 in 0.222s (37186 points)\nFusing image [5/162] with index 113 in 0.226s (42273 points)\nFusing image [6/162] with index 116 in 0.229s (46852 points)\nFusing image [7/162] with index 72 in 0.227s (50852 points)\nFusing image [8/162] with index 71 in 0.229s (54892 points)\nFusing image [9/162] with index 70 in 0.227s (58371 points)\nFusing image [10/162] with index 69 in 0.224s (61559 points)\nFusing image [11/162] with index 68 in 0.222s (64557 points)\nFusing image [12/162] with index 67 in 0.226s (68053 points)\nFusing image [13/162] with index 66 in 0.219s (71218 points)\nFusing image [14/162] with index 65 in 0.218s (74363 points)\nFusing image [15/162] with index 64 in 0.218s (77857 points)\nFusing image [16/162] with index 63 in 0.215s (80648 points)\nFusing image [17/162] with index 62 in 0.223s (85265 points)\nFusing image [18/162] with index 61 in 0.220s (89907 points)\nFusing image [19/162] with index 60 in 0.214s (93356 points)\nFusing image [20/162] with index 59 in 0.219s (96925 points)\nFusing image [21/162] with index 58 in 0.216s (100251 points)\nFusing image [22/162] with index 57 in 0.216s (103530 points)\nFusing image [23/162] with index 56 in 0.216s (106977 points)\nFusing image [24/162] with index 55 in 0.214s (110304 points)\nFusing image [25/162] with index 54 in 0.222s (113251 points)\nFusing image [26/162] with index 53 in 0.221s (117261 points)\nFusing image [27/162] with index 52 in 0.220s (120304 points)\nFusing image [28/162] with index 51 in 0.222s (123759 points)\nFusing image [29/162] with index 50 in 0.216s (126563 points)\nFusing image [30/162] with index 49 in 0.214s (130107 points)\nFusing image [31/162] with index 48 in 0.214s (133225 points)\nFusing image [32/162] with index 47 in 0.213s (135537 points)\nFusing image [33/162] with index 46 in 0.215s (137764 points)\nFusing image [34/162] with index 45 in 0.211s (139820 points)\nFusing image [35/162] with index 44 in 0.210s (141888 points)\nFusing image [36/162] with index 43 in 0.213s (144368 points)\nFusing image [37/162] with index 40 in 0.215s (146882 points)\nFusing image [38/162] with index 39 in 0.214s (149901 points)\nFusing image [39/162] with index 38 in 0.212s (153590 points)\nFusing image [40/162] with index 37 in 0.215s (156371 points)\nFusing image [41/162] with index 36 in 0.221s (162171 points)\nFusing image [42/162] with index 35 in 0.218s (165922 points)\nFusing image [43/162] with index 34 in 0.220s (170363 points)\nFusing image [44/162] with index 33 in 0.221s (174853 points)\nFusing image [45/162] with index 32 in 0.217s (178376 points)\nFusing image [46/162] with index 31 in 0.218s (182134 points)\nFusing image [47/162] with index 30 in 0.217s (185914 points)\nFusing image [48/162] with index 29 in 0.219s (189740 points)\nFusing image [49/162] with index 28 in 0.217s (192779 points)\nFusing image [50/162] with index 27 in 0.218s (195531 points)\nFusing image [51/162] with index 26 in 0.229s (199576 points)\nFusing image [52/162] with index 25 in 0.231s (203526 points)\nFusing image [53/162] with index 24 in 0.229s (207761 points)\nFusing image [54/162] with index 23 in 0.226s (211890 points)\nFusing image [55/162] with index 22 in 0.230s (216627 points)\nFusing image [56/162] with index 21 i ...

# %%
# %%time
client.containers.run('colmap:test', CMD7 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False)
# Out:
# CPU times: user 23.6 ms, sys: 3.64 ms, total: 27.3 ms
# Wall time: 700 ms
# b''

# %% [markdown]
# #  Visualization

# %%
import numpy as np
import open3d as o3d
import vedo

#embedded vedo in jupyter
vedo.settings.embedWindow(backend='ipyvtk', verbose=True)

# %%
local_path_to_dense_pc = "/home/liteandfog/Desktop/raspi-plant/output3/dense.ply"

# %%
#%%time
#o3d.visualization.draw_geometries([o3d.io.read_point_cloud(local_path_to_dense_pc)])  # Visualize the point cloud

# %%
vedo.show(local_path_to_dense_pc, axes=True)
# Out:
# ViewInteractiveWidget(height=720, layout=Layout(height='auto', width='100%'), width=720)

# %% [markdown]
# ####

# %%
##  Visualization: Poisson's mesh

# %%
# %%time
cloud = o3d.io.read_point_cloud(local_path_to_dense_pc)
poisson_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(cloud, depth=12, width=0, scale=1.1, linear_fit=False)[0]
# Out:
# CPU times: user 3min 3s, sys: 30 s, total: 3min 34s
# Wall time: 21.1 s
# [WARNING] /home/liteandfog/Open3D/build/poisson/src/ext_poisson/PoissonRecon/Src/FEMTree.IsoSurface.specialized.inl (Line 1858)
#           Extract
#           bad average roots: 4

# %%
local_path_to_poison_mesh = f"/home/liteandfog/raspi-plant/output/poisson.ply"
o3d.io.write_triangle_mesh(local_path_to_poison_mesh, poisson_mesh, write_ascii=True, compressed=False)
# Out:
# [Open3D WARNING] Write Ply clamped color value to valid range
# True

# %%
vedo.show(local_path_to_poison_mesh)
# Out:
# ViewInteractiveWidget(height=720, layout=Layout(height='auto', width='100%'), width=720)

# %% [markdown]
# # Outliers and isolated points removal.

# %%
def create_outliers_cloud(pcd):
    pcd_colors = np.asarray(pcd.colors)*255
    pcd_colors_summed = np.expand_dims(pcd_colors.sum(axis=1), axis=1)
    outliers_ind = np.where(np.any(pcd_colors_summed > 720,axis = 1))[0].tolist()
    return pcd.select_by_index(outliers_ind,invert=True),pcd.select_by_index(outliers_ind,invert=False)

# %%
inliers_cloud, outliers_cloud = create_outliers_cloud(cloud)

# %%
o3d.visualization.draw_geometries([inliers_cloud])

# %%
local_path_to_inliers_cloud = f"/home/liteandfog/raspi-plant/output/inliers_cloud.ply"
local_path_to_outliers_cloud = f"/home/liteandfog/raspi-plant/output/outliers_cloud.ply"
local_path_to_inliers_xpcd_cloud = f"/home/liteandfog/raspi-plant/output/inliers_xpcd_cloud.ply"

o3d.io.write_point_cloud(local_path_to_inliers_cloud, inliers_cloud, write_ascii=True, compressed=False)
o3d.io.write_point_cloud(local_path_to_outliers_cloud, outliers_cloud, write_ascii=True, compressed=False)
xpcd, _ = inliers_cloud.remove_statistical_outlier(nb_neighbors=5,std_ratio=2.0)

# %%
vedo.show(local_path_to_inliers_cloud)
# Out:
# ViewInteractiveWidget(height=720, layout=Layout(height='auto', width='100%'), width=720)

# %%
vedo.show(local_path_to_outliers_cloud)
# Out:
# ViewInteractiveWidget(height=720, layout=Layout(height='auto', width='100%'), width=720)

# %%
#o3d.visualization.draw_geometries([poisson_mesh])
#o3d.visualization.draw_geometries([xpcd])
#o3d.visualization.draw_geometries([outliers_cloud])
#o3d.visualization.draw_geometries([inliers_cloud])

# %% [markdown]
# # Poisson mesher - cleansed cloud

# %%
poisson_mesh_cleansed = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(xpcd, depth=14, width=0, scale=1.1, linear_fit=False)[0]
local_path_to_poisson_mesh_cleansed = f"/home/liteandfog/raspi-plant/output/poisson_cleansed.ply"
o3d.io.write_triangle_mesh(local_path_to_poisson_mesh_cleansed, poisson_mesh_cleansed, write_ascii=True, compressed=False)
# Out:
# True

# %%
vedo.show(local_path_to_poisson_mesh_cleansed)
# Out:
# ViewInteractiveWidget(height=720, layout=Layout(height='auto', width='100%'), width=720)
