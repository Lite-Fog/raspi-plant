# %% [markdown]
# # Colmap container

# %%
import docker
serial = str(2)

path_to_mount = '/home/liteandfog/raspi-plant/d/dataset'+serial
path_masked_to_mount = '/home/liteandfog/raspi-plant/d/dataset-m'+serial
path_output_to_mount = '/home/liteandfog/raspi-plant/d/output'+serial

WD="/root/data"
destination_mount = '/root/data/dataset'
destination_masked_mount = '/root/data/dataset-m'
destination_output_mount = '/root/data/output'

mount_dict = {path_to_mount: {'bind': destination_mount, 'mode': 'rw'},
              path_masked_to_mount: {'bind': destination_masked_mount, 'mode': 'rw'},
              path_output_to_mount: {'bind': destination_output_mount, 'mode': 'rw'}}

#semi- environment variables.

DATASET_PATH="/root/data"

DATABASE_PATH="/root/data/output/database.db"

IMAGESET_PATH="/root/data/dataset-m"

OUTPUT_PATH="/root/data/output"

SPARSE_PATH="/root/data/output/0"

NEW_SPARSE_PATH="/root/data/output/sparse"

DENSE_PATH="/root/data/output"

DENSE_PLY_PATH="/root/data/output/dense.ply"

# %% [markdown]
# # COLMAP's pipeline

# %%
# feature_extractor
CMD1 = f"colmap feature_extractor --database_path {DATABASE_PATH} --image_path {IMAGESET_PATH}"

# exhaustive_matcher
CMD2 = f"colmap exhaustive_matcher \
   --database_path {DATABASE_PATH}"

# colmap mapper
CMD3 = f"colmap mapper \
    --database_path {DATABASE_PATH} \
    --image_path {IMAGESET_PATH} \
    --output_path {OUTPUT_PATH}"

# colmap image_undistorter
CMD4 = f"colmap image_undistorter \
    --image_path {IMAGESET_PATH} \
    --input_path {SPARSE_PATH} \
    --output_path {DENSE_PATH} \
    --output_type COLMAP"

# colmap patch_match_stereo
CMD5 = f"colmap patch_match_stereo \
    --workspace_path {DENSE_PATH} \
    --workspace_format COLMAP \
    --PatchMatchStereo.geom_consistency true"

# colmap stereo_fusion
CMD6 = f"colmap stereo_fusion \
    --workspace_path {DENSE_PATH} \
    --workspace_format COLMAP \
    --input_type geometric \
    --output_path {DENSE_PLY_PATH}"

### converter (bytes into text)
CMD7 = f"colmap model_converter \
    --input_path {SPARSE_PATH} \
    --output_path {SPARSE_PATH} \
    --output_type BIN"

# %%
# %%time
client = docker.from_env()
# Out:
# CPU times: user 8.39 ms, sys: 0 ns, total: 8.39 ms
# Wall time: 16 ms

# %%
# %%time
client.containers.run('colmap:test', CMD1 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False, auto_remove=True)
# Out:
# CPU times: user 42.6 ms, sys: 0 ns, total: 42.6 ms
# Wall time: 49.5 s
# b'\n==============================================================================\nFeature extraction\n==============================================================================\n\nProcessed file [1/58]\n  Name:            gr_img2021-08-19 13:58:24.090844.jpg\n  Dimensions:      800 x 720\n  Camera:          #1 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        2800\nProcessed file [2/58]\n  Name:            gr_img2021-08-19 13:58:24.589020.jpg\n  Dimensions:      800 x 720\n  Camera:          #2 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        2908\nProcessed file [3/58]\n  Name:            gr_img2021-08-19 13:58:25.084892.jpg\n  Dimensions:      800 x 720\n  Camera:          #3 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        2700\nProcessed file [4/58]\n  Name:            gr_img2021-08-19 13:58:25.587140.jpg\n  Dimensions:      800 x 720\n  Camera:          #4 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        2925\nProcessed file [5/58]\n  Name:            gr_img2021-08-19 13:58:26.089117.jpg\n  Dimensions:      800 x 720\n  Camera:          #5 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        2912\nProcessed file [6/58]\n  Name:            gr_img2021-08-19 13:58:26.588615.jpg\n  Dimensions:      800 x 720\n  Camera:          #6 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        2910\nProcessed file [7/58]\n  Name:            gr_img2021-08-19 13:58:27.085802.jpg\n  Dimensions:      800 x 720\n  Camera:          #7 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        2897\nProcessed file [8/58]\n  Name:            gr_img2021-08-19 13:58:27.583417.jpg\n  Dimensions:      800 x 720\n  Camera:          #8 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        2974\nProcessed file [9/58]\n  Name:            gr_img2021-08-19 13:58:28.086960.jpg\n  Dimensions:      800 x 720\n  Camera:          #9 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3137\nProcessed file [10/58]\n  Name:            gr_img2021-08-19 13:58:28.588199.jpg\n  Dimensions:      800 x 720\n  Camera:          #10 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3137\nProcessed file [11/58]\n  Name:            gr_img2021-08-19 13:58:29.084209.jpg\n  Dimensions:      800 x 720\n  Camera:          #11 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3165\nProcessed file [12/58]\n  Name:            gr_img2021-08-19 13:58:29.586948.jpg\n  Dimensions:      800 x 720\n  Camera:          #12 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3230\nProcessed file [13/58]\n  Name:            gr_img2021-08-19 13:58:30.083936.jpg\n  Dimensions:      800 x 720\n  Camera:          #13 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3151\nProcessed file [14/58]\n  Name:            gr_img2021-08-19 13:58:30.586236.jpg\n  Dimensions:      800 x 720\n  Camera:          #14 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3190\nProcessed file [15/58]\n  Name:            gr_img2021-08-19 13:58:31.087570.jpg\n  Dimensions:      800 x 720\n  Camera:          #15 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3218\nProcessed file [16/58]\n  Name:            gr_img2021-08-19 13:58:31.582496.jpg\n  Dimensions:      800 x 720\n  Camera:          #16 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3222\nProcessed file [17/58]\n  Name:            gr_img2021-08-19 13:58:32.082580.jpg\n  Dimensions:      800 x 720\n  Camera:          #17 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3448\nProcessed file [18/58]\n  Name:            gr_img2021-08-19 13:58:32.586020.jpg\n  Dimensions:      800 x 720\n  Camera:          #18 - SIMPLE_RADIAL\n  Focal Length:    960.00px\n  Features:        3298\nProcessed file [19/58]\n  Name:            gr_img2021-08-19 13:58:33.086386.jpg\n  Dimensions:      800 x 720\n  Camera:          #19 - SIMPLE ...

# %%
# %%time
client.containers.run('colmap:test', CMD2 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 27.7 ms, sys: 0 ns, total: 27.7 ms
# Wall time: 1min 1s
# b'\n==============================================================================\nExhaustive feature matching\n==============================================================================\n\nMatching block [1/2, 1/2] in 9.306s\nMatching block [1/2, 2/2] in 0.127s\nMatching block [2/2, 1/2] in 2.994s\nMatching block [2/2, 2/2] in 0.203s\nElapsed time: 1.015 [minutes]\n'

# %%
# %%time
client.containers.run('colmap:test', CMD3 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 150 ms, sys: 0 ns, total: 150 ms
# Wall time: 52.5 s
# b"\n==============================================================================\nLoading database\n==============================================================================\n\nLoading cameras... 58 in 0.000s\nLoading matches... 258 in 0.002s\nLoading images... 58 in 0.010s (connected 58)\nBuilding correspondence graph... in 0.009s (ignored 0)\n\nElapsed time: 0.000 [minutes]\n\n\n==============================================================================\nFinding good initial image pair\n==============================================================================\n\n\n==============================================================================\nInitializing with image pair #58 and #6\n==============================================================================\n\n\n==============================================================================\nGlobal bundle adjustment\n==============================================================================\n\niter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time\n   0  1.469553e+02    0.00e+00    5.68e+03   0.00e+00   0.00e+00  1.00e+04        0    8.63e-04    2.31e-03\n   1  3.322630e+02   -1.85e+02    0.00e+00   7.48e+01  -1.95e+00  5.00e+03        1    1.13e-03    3.45e-03\n   2  2.798113e+02   -1.33e+02    0.00e+00   6.38e+01  -1.42e+00  1.25e+03        1    2.35e-04    3.70e-03\n   3  1.415288e+02    5.43e+00    9.73e+03   3.89e+01   6.56e-02  7.55e+02        1    6.75e-04    4.38e-03\n   4  5.558891e+01    8.59e+01    3.71e+02   1.34e+01   9.96e-01  2.26e+03        1    6.75e-04    5.06e-03\n   5  5.183470e+01    3.75e+00    1.70e+02   1.58e+01   9.79e-01  6.79e+03        1    6.77e-04    5.74e-03\n   6  5.093310e+01    9.02e-01    5.61e+01   1.51e+01   1.00e+00  2.04e+04        1    6.74e-04    6.42e-03\n   7  5.060676e+01    3.26e-01    4.76e+02   2.24e+01   8.90e-01  3.87e+04        1    6.74e-04    7.10e-03\n   8  5.037881e+01    2.28e-01    5.18e+02   2.53e+01   7.01e-01  4.14e+04        1    6.91e-04    7.80e-03\n   9  5.017966e+01    1.99e-01    2.07e+02   1.60e+01   9.24e-01  1.06e+05        1    6.77e-04    8.48e-03\n  10  5.012049e+01    5.92e-02    1.73e+02   1.45e+01   8.32e-01  1.50e+05        1    6.75e-04    9.16e-03\n  11  5.010118e+01    1.93e-02    2.59e+01   5.47e+00   9.91e-01  4.49e+05        1    6.77e-04    9.85e-03\n  12  5.010032e+01    8.62e-04    3.00e+00   1.70e+00   1.01e+00  1.35e+06        1    6.75e-04    1.05e-02\n  13  5.010029e+01    2.07e-05    1.01e+00   2.14e-01   1.01e+00  4.04e+06        1    6.75e-04    1.12e-02\n  14  5.010031e+01   -1.20e-05    0.00e+00   1.34e+00  -6.28e-01  2.02e+06        1    2.45e-04    1.15e-02\n  15  5.010029e+01    7.83e-06    2.42e+00   6.60e-01   8.03e-01  2.60e+06        1    6.70e-04    1.21e-02\n  16  5.010028e+01    8.64e-06    4.01e+00   8.68e-01   6.18e-01  2.63e+06        1    6.76e-04    1.28e-02\n  17  5.010027e+01    1.19e-05    4.10e+00   8.79e-01   6.81e-01  2.76e+06        1    6.75e-04    1.35e-02\n  18  5.010025e+01    1.16e-05    4.51e+00   9.22e-01   6.33e-01  2.82e+06        1    6.74e-04    1.42e-02\n  19  5.010024e+01    1.25e-05    4.66e+00   9.38e-01   6.34e-01  2.87e+06        1    6.76e-04    1.49e-02\n  20  5.010023e+01    1.26e-05    4.83e+00   9.54e-01   6.21e-01  2.91e+06        1    7.17e-04    1.56e-02\n  21  5.010022e+01    1.29e-05    4.95e+00   9.66e-01   6.15e-01  2.95e+06        1    6.75e-04    1.63e-02\n  22  5.010020e+01    1.30e-05    5.06e+00   9.76e-01   6.08e-01  2.98e+06        1    6.73e-04    1.69e-02\n  23  5.010019e+01    1.32e-05    5.15e+00   9.85e-01   6.03e-01  3.01e+06        1    6.75e-04    1.76e-02\n  24  5.010018e+01    1.33e-05    5.22e+00   9.92e-01   5.99e-01  3.03e+06        1    6.75e-04    1.83e-02\n  25  5.010016e+01    1.34e-05    5.28e+00   9.98e-01   5.95e-01  3.05e+06        1    6.74e-04    1.90e-02\n  26  5.010015e+01    1.34e-05    5.34e+00   1.00e+00   5.92e-01  3.07e+06   ...

# %%
# %%time
client.containers.run('colmap:test', CMD4 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 29.6 ms, sys: 0 ns, total: 29.6 ms
# Wall time: 1.2 s
# b'\n==============================================================================\nReading reconstruction\n==============================================================================\n\n => Reconstruction with 58 images and 9521 points\n\n==============================================================================\nImage undistortion\n==============================================================================\n\nUndistorting image [1/58]\nUndistorting image [2/58]\nUndistorting image [3/58]\nUndistorting image [4/58]\nUndistorting image [5/58]\nUndistorting image [6/58]\nUndistorting image [7/58]\nUndistorting image [8/58]\nUndistorting image [9/58]\nUndistorting image [10/58]\nUndistorting image [11/58]\nUndistorting image [12/58]\nUndistorting image [13/58]\nUndistorting image [14/58]\nUndistorting image [15/58]\nUndistorting image [16/58]\nUndistorting image [17/58]\nUndistorting image [18/58]\nUndistorting image [19/58]\nUndistorting image [20/58]\nUndistorting image [21/58]\nUndistorting image [22/58]\nUndistorting image [23/58]\nUndistorting image [24/58]\nUndistorting image [25/58]\nUndistorting image [26/58]\nUndistorting image [27/58]\nUndistorting image [28/58]\nUndistorting image [29/58]\nUndistorting image [30/58]\nUndistorting image [31/58]\nUndistorting image [32/58]\nUndistorting image [33/58]\nUndistorting image [34/58]\nUndistorting image [35/58]\nUndistorting image [36/58]\nUndistorting image [37/58]\nUndistorting image [38/58]\nUndistorting image [39/58]\nUndistorting image [40/58]\nUndistorting image [41/58]\nUndistorting image [42/58]\nUndistorting image [43/58]\nUndistorting image [44/58]\nUndistorting image [45/58]\nUndistorting image [46/58]\nUndistorting image [47/58]\nUndistorting image [48/58]\nUndistorting image [49/58]\nUndistorting image [50/58]\nUndistorting image [51/58]\nUndistorting image [52/58]\nUndistorting image [53/58]\nUndistorting image [54/58]\nUndistorting image [55/58]\nUndistorting image [56/58]\nUndistorting image [57/58]\nUndistorting image [58/58]\nWriting reconstruction...\nWriting configuration...\nWriting scripts...\nElapsed time: 0.009 [minutes]\n'

# %%
# %%time
client.containers.run('colmap:test', CMD5 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 219 ms, sys: 15.5 ms, total: 235 ms
# Wall time: 20min 50s
# b'Reading workspace...\nReading configuration...\nConfiguration has 58 problems...\n\n==============================================================================\nProcessing view 1 / 58 for gr_img2021-08-19 13:58:24.090844.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 33\nsrc_image_idxs: 10 31 8 37 30 7 29 6 36 0 35 28 5 34 1 27 4 2 9 32\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 2.32738\ndepth_max: 5.11961\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consistency_regularizer: 0.3\ngeom_consistency_max_cost: 3\nfilter: 0\nfilter_min_ncc: 0.1\nfilter_min_triangulation_angle: 3\nfilter_min_num_consistent: 2\nfilter_geom_consistency_max_cost: 1\nwrite_consistency_graph: 0\nallow_missing_files: 0\n\nPatchMatch::Run\n---------------\nInitialization: 0.1013s\n Sweep 1: 0.4428s\n Sweep 2: 0.5334s\n Sweep 3: 0.4216s\n Sweep 4: 0.5301s\nIteration 1: 1.9280s\n Sweep 1: 0.4192s\n Sweep 2: 0.5268s\n Sweep 3: 0.4203s\n Sweep 4: 0.5170s\nIteration 2: 1.8834s\n Sweep 1: 0.4190s\n Sweep 2: 0.5160s\n Sweep 3: 0.4199s\n Sweep 4: 0.5059s\nIteration 3: 1.8609s\n Sweep 1: 0.4175s\n Sweep 2: 0.5056s\n Sweep 3: 0.4148s\n Sweep 4: 0.4958s\nIteration 4: 1.8337s\n Sweep 1: 0.4152s\n Sweep 2: 0.4943s\n Sweep 3: 0.4161s\n Sweep 4: 0.4865s\nIteration 5: 1.8122s\nTotal: 9.4196s\n\nWriting photometric output for gr_img2021-08-19 13:58:24.090844.jpg\n\n==============================================================================\nProcessing view 2 / 58 for gr_img2021-08-19 13:58:24.589020.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 32\nsrc_image_idxs: 9 30 7 8 31 29 6 37 28 5 36 27 4 0 35 3 34 10 33 1\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 2.32478\ndepth_max: 5.1892\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consistency_regularizer: 0.3\ngeom_consistency_max_cost: 3\nfilter: 0\nfilter_min_ncc: 0.1\nfilter_min_triangulation_angle: 3\nfilter_min_num_consistent: 2\nfilter_geom_consistency_max_cost: 1\nwrite_consistency_graph: 0\nallow_missing_files: 0\n\nPatchMatch::Run\n---------------\nInitialization: 0.0878s\n Sweep 1: 0.4198s\n Sweep 2: 0.5328s\n Sweep 3: 0.4209s\n Sweep 4: 0.5301s\nIteration 1: 1.9038s\n Sweep 1: 0.4194s\n Sweep 2: 0.5251s\n Sweep 3: 0.4207s\n Sweep 4: 0.5180s\nIteration 2: 1.8833s\n Sweep 1: 0.4186s\n Sweep 2: 0.5139s\n Sweep 3: 0.4202s\n Sweep 4: 0.5059s\nIteration 3: 1.8586s\n Sweep 1: 0.4166s\n Sweep 2: 0.5031s\n Sweep 3: 0.4155s\n Sweep 4: 0.4953s\nIteration 4: 1.8305s\n Sweep 1: 0.4158s\n Sweep 2: 0.4933s\n Sweep 3: 0.4156s\n Sweep 4: 0.4845s\nIteration 5: 1.8092s\nTotal: 9.3732s\n\nWriting photometric output for gr_img2021-08-19 13:58:24.589020.jpg\n\n==============================================================================\nProcessing view 3 / 58 for gr_img2021-08-19 13:58:25.084892.jpg\n==============================================================================\n\nReading inputs...\n\nPatchMatch::Problem\n-------------------\nref_image_idx: 34\nsrc_image_idxs: 7 30 29 6 8 31 28 5 37 27 4 26 3 36 33 2 0 35 9 32\n\nPatchMatchOptions\n-----------------\nmax_image_size: -1\ngpu_index: 0\ndepth_min: 2.37368\ndepth_max: 5.2784\nwindow_radius: 5\nwindow_step: 1\nsigma_spatial: 5\nsigma_color: 0.2\nnum_samples: 15\nncc_sigma: 0.6\nmin_triangulation_angle: 1\nincident_angle_sigma: 0.9\nnum_iterations: 5\ngeom_consistency: 0\ngeom_consistency_regularizer: 0.3\ngeom_consistency_max_cost: 3\nfi ...

# %%
# %%time
client.containers.run('colmap:test', CMD6 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False,auto_remove=True)
# Out:
# CPU times: user 27.6 ms, sys: 172 µs, total: 27.8 ms
# Wall time: 10.2 s
# b'\nStereoFusion::Options\n---------------------\nmask_path: \nmax_image_size: -1\nmin_num_pixels: 5\nmax_num_pixels: 10000\nmax_traversal_depth: 100\nmax_reproj_error: 2\nmax_depth_error: 0.01\nmax_normal_error: 10\ncheck_num_images: 50\nuse_cache: 0\ncache_size: 32\nbbox_min: -3.40282e+38 -3.40282e+38 -3.40282e+38\nbbox_max: 3.40282e+38 3.40282e+38 3.40282e+38\n\nReading workspace...\nLoading workspace data with 16 threads...\nElapsed time: 0.005 [minutes]\nReading configuration...\nStarting fusion with 16 threads\nFusing image [1/58] with index 0 in 0.281s (53147 points)\nFusing image [2/58] with index 35 in 0.157s (66851 points)\nFusing image [3/58] with index 34 in 0.160s (82434 points)\nFusing image [4/58] with index 1 in 0.143s (89351 points)\nFusing image [5/58] with index 32 in 0.153s (101619 points)\nFusing image [6/58] with index 2 in 0.133s (105714 points)\nFusing image [7/58] with index 33 in 0.146s (113284 points)\nFusing image [8/58] with index 3 in 0.133s (116106 points)\nFusing image [9/58] with index 4 in 0.150s (122099 points)\nFusing image [10/58] with index 5 in 0.154s (129123 points)\nFusing image [11/58] with index 6 in 0.152s (136202 points)\nFusing image [12/58] with index 7 in 0.156s (143776 points)\nFusing image [13/58] with index 8 in 0.151s (150367 points)\nFusing image [14/58] with index 9 in 0.151s (159351 points)\nFusing image [15/58] with index 10 in 0.150s (167055 points)\nFusing image [16/58] with index 11 in 0.150s (174474 points)\nFusing image [17/58] with index 12 in 0.150s (181712 points)\nFusing image [18/58] with index 13 in 0.153s (188998 points)\nFusing image [19/58] with index 14 in 0.148s (195305 points)\nFusing image [20/58] with index 15 in 0.156s (202841 points)\nFusing image [21/58] with index 16 in 0.153s (209923 points)\nFusing image [22/58] with index 17 in 0.149s (216635 points)\nFusing image [23/58] with index 18 in 0.151s (222599 points)\nFusing image [24/58] with index 19 in 0.154s (229097 points)\nFusing image [25/58] with index 20 in 0.153s (236005 points)\nFusing image [26/58] with index 21 in 0.152s (242121 points)\nFusing image [27/58] with index 57 in 0.152s (248178 points)\nFusing image [28/58] with index 56 in 0.154s (254707 points)\nFusing image [29/58] with index 55 in 0.149s (261039 points)\nFusing image [30/58] with index 54 in 0.151s (266897 points)\nFusing image [31/58] with index 53 in 0.150s (273344 points)\nFusing image [32/58] with index 52 in 0.153s (280056 points)\nFusing image [33/58] with index 51 in 0.148s (286527 points)\nFusing image [34/58] with index 50 in 0.153s (293611 points)\nFusing image [35/58] with index 49 in 0.154s (299924 points)\nFusing image [36/58] with index 48 in 0.155s (307275 points)\nFusing image [37/58] with index 47 in 0.158s (315202 points)\nFusing image [38/58] with index 46 in 0.162s (323816 points)\nFusing image [39/58] with index 45 in 0.160s (332508 points)\nFusing image [40/58] with index 44 in 0.159s (342121 points)\nFusing image [41/58] with index 43 in 0.156s (350985 points)\nFusing image [42/58] with index 42 in 0.153s (358931 points)\nFusing image [43/58] with index 41 in 0.153s (367585 points)\nFusing image [44/58] with index 40 in 0.151s (375515 points)\nFusing image [45/58] with index 39 in 0.146s (383550 points)\nFusing image [46/58] with index 38 in 0.147s (390671 points)\nFusing image [47/58] with index 22 in 0.147s (396804 points)\nFusing image [48/58] with index 23 in 0.142s (402451 points)\nFusing image [49/58] with index 24 in 0.146s (407105 points)\nFusing image [50/58] with index 25 in 0.143s (411454 points)\nFusing image [51/58] with index 26 in 0.139s (415718 points)\nFusing image [52/58] with index 27 in 0.137s (418613 points)\nFusing image [53/58] with index 28 in 0.133s (420761 points)\nFusing image [54/58] with index 29 in 0.136s (422281 points)\nFusing image [55/58] with index 30 in 0.133s (422924 points)\nFusing image [56/58] with index 31 in 0.131s (423145 points)\nFusing image [57/58] with in ...

# %%
# %%time
client.containers.run('colmap:test', CMD7 ,volumes=mount_dict,working_dir=WD, runtime="nvidia",detach=False)
# Out:
# CPU times: user 26.5 ms, sys: 85 µs, total: 26.6 ms
# Wall time: 681 ms
# b''

# %% [markdown]
# #  Visualization: dense point cloud

# %%
local_path_to_dense_pc = f"/home/liteandfog/raspi-plant/d/output{serial}/dense.ply"

# %%
import numpy as np
import open3d as o3d
from open3d.web_visualizer import draw
o3d.visualization.webrtc_server.enable_webrtc()
# Out:
# [Open3D INFO] WebRTC GUI backend enabled.

# %%
cloud = o3d.io.read_point_cloud(local_path_to_dense_pc)

# %%
# %%time
#o3d.visualization.draw_geometries([cloud])  # Visualize the point cloud
# Out:
# CPU times: user 3 µs, sys: 5 µs, total: 8 µs
# Wall time: 9.3 µs

# %%
o3d.visualization.draw_geometries([cloud], zoom=0.3412,
                                  front=[0.4257, -0.2125, -0.8795],
                                  lookat=[2.6172, 2.0475, 1.532],
                                  up=[-0.0694, -0.9768, 0.2024])

# %%
draw(cloud)
# Out:
# [Open3D INFO] Window window_1 created.
# WebVisualizer(window_uid='window_1')
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.48274796410531495
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.48274796410531495
# [Open3D INFO] Sending init frames to window_1.

# %%
##  Visualization: first mesh

# %%
# %%time
poisson_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(cloud, depth=12, width=0, scale=1.1, linear_fit=False)[0]
# Out:
# CPU times: user 8min 23s, sys: 1min, total: 9min 24s
# Wall time: 49.6 s
# [1225:083][1111739] (stun_port.cc:96): Binding request timed out from 10.150.180.x:60202 (enp5s0)
# [1225:083][1111739] (stun_port.cc:96): Binding request timed out from 192.168.11.x:47875 (wlp3s0)
# [WARNING] /home/runner/work/Open3D/Open3D/3rdparty/PoissonRecon/PoissonRecon/Src/FEMTree.IsoSurface.specialized.inl (Line 1858)
#           Extract
#           bad average roots: 1

# %%
draw(poisson_mesh)
# Out:
# [Open3D INFO] Window window_2 created.
# WebVisualizer(window_uid='window_2')
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.7199711833979527
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.7199711833979527
# [Open3D INFO] Sending init frames to window_2.
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate

# %% [markdown]
# # Outliers and isolated points removal.

# %%
def create_outliers_cloud(pcd):
    pcd_colors = np.asarray(pcd.colors)*255
    pcd_colors_summed = np.expand_dims(pcd_colors.sum(axis=1), axis=1)
    outliers_ind = np.where(np.any(pcd_colors_summed > 720,axis = 1))[0].tolist()
    return pcd.select_by_index(outliers_ind,invert=True),pcd.select_by_index(outliers_ind,invert=False)

# %%
inlier_cloud,outlier_cloud=create_outliers_cloud(cloud)
#o3d.visualization.draw_geometries([inlier_cloud])

# %%
xpcd, _ = inlier_cloud.remove_statistical_outlier(nb_neighbors=5,std_ratio=2.0)

# %%
draw(xpcd)
# Out:
# [Open3D INFO] Window window_3 created.
# WebVisualizer(window_uid='window_3')
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.09317631142283989
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.09317631142283989
# [Open3D INFO] Sending init frames to window_3.
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate

# %% [markdown]
# ## White pigments outliers

# %%
draw(outlier_cloud)
# Out:
# WebVisualizer(window_uid='window_4')
# [Open3D INFO] Window window_4 created.
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.19605168645284254
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.19605168645284254
# [Open3D INFO] Sending init frames to window_4.
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate
# [1290:324][1111739] (stun_port.cc:96): Binding request timed out from 10.150.180.x:36089 (enp5s0)
# [1290:324][1111739] (stun_port.cc:96): Binding request timed out from 192.168.11.x:44737 (wlp3s0)

# %% [markdown]
# # Poisson mesher - cleansed cloud

# %%
poisson_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(xpcd, depth=14, width=0, scale=1.1, linear_fit=False)[0]
# Out:
# [1309:721][1111739] (stun_port.cc:96): Binding request timed out from 10.150.180.x:59445 (enp5s0)
# [1309:721][1111739] (stun_port.cc:96): Binding request timed out from 192.168.11.x:43248 (wlp3s0)
# [1323:932][1111739] (stun_port.cc:96): Binding request timed out from 10.150.180.x:41717 (enp5s0)
# [1323:933][1111739] (stun_port.cc:96): Binding request timed out from 192.168.11.x:34487 (wlp3s0)

# %%
o3d.visualization.draw_geometries([poisson_mesh])

# %%
draw(poisson_mesh)
# Out:
# [Open3D INFO] Window window_5 created.
# WebVisualizer(window_uid='window_5')
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.9541683202015951
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.9541683202015951
# [Open3D INFO] Sending init frames to window_5.
# [1502:494][1111739] (stun_port.cc:96): Binding request timed out from 10.150.180.x:36261 (enp5s0)
# [1502:494][1111739] (stun_port.cc:96): Binding request timed out from 192.168.11.x:33303 (wlp3s0)
